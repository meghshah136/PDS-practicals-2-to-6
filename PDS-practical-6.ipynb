# %%
import numpy as np
import pandas as pd

# %%
dataframe = pd.read_csv("loan_data_set.csv")

# %%
#Customers having Applicant Income more than 5000 and urban property area ... 
dataframe.loc[(dataframe['ApplicantIncome']>=5000) & (dataframe['Property_Area']=='Urban')]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# 5    LP001011   Male     Yes          2      Graduate           Yes
# 20   LP001043   Male     Yes          0  Not Graduate            No
# 21   LP001046   Male     Yes          1      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 594  LP002938   Male     Yes          0      Graduate           Yes
# 599  LP002948   Male     Yes          2      Graduate            No
# 602  LP002953   Male     Yes         3+      Graduate            No
# 611  LP002983   Male     Yes          1      Graduate            No
# 612  LP002984   Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
dataframe.loc[(dataframe['ApplicantIncome']>=5000) & (dataframe['Property_Area']=='Urban')].describe
# Out:
# <bound method NDFrame.describe of       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# 5    LP001011   Male     Yes          2      Graduate           Yes
# 20   LP001043   Male     Yes          0  Not Graduate            No
# 21   LP001046   Male     Yes          1      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 594  LP002938   Male     Yes          0      Graduate           Yes
# 599  LP002948   Male     Yes          2      Graduate            No
# 602  LP002953   Male     Yes         3+      Graduate            No
# 611  LP002983   Male     Yes          1      Graduate            No
# 612  LP002984   Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#Customers having Coapplicant Income more than 10000 and urban property area ... 
dataframe.loc[(dataframe['CoapplicantIncome']>=10000) & (dataframe['Property_Area']=='Urban')]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 417  LP002342    Male     Yes          2  Graduate           Yes
# 581  LP002893    Male      No          0  Graduate            No
# 600  LP002949  Female      No         3+  Graduate           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 417             1600            20000.0       239.0             360.0
# 581             1836            33837.0        90.0             360.0
# 600              416            41667.0       350.0             180.0
#
#      Credit_History Property_Area Loan_Status
# 417             1.0         Urban           N
# 581             1.0         Urban           N
# 600             NaN         Urban           N

# %%
dataframe.loc[(dataframe['CoapplicantIncome']>=10000) & (dataframe['Property_Area']=='Urban')].describe
# Out:
# <bound method NDFrame.describe of       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 417  LP002342    Male     Yes          2  Graduate           Yes
# 581  LP002893    Male      No          0  Graduate            No
# 600  LP002949  Female      No         3+  Graduate           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 417             1600            20000.0       239.0             360.0
# 581             1836            33837.0        90.0             360.0
# 600              416            41667.0       350.0             180.0
#
#      Credit_History Property_Area Loan_Status
# 417             1.0         Urban           N
# 581             1.0         Urban           N
# 600             NaN         Urban           N  >

# %%
#Customers having Coapplicant Income more than 5000 and rural property area ... 
dataframe.loc[(dataframe['CoapplicantIncome']>=5000) & (dataframe['Property_Area']=='Rural')]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 181  LP001634   Male      No          0      Graduate            No
# 188  LP001644    NaN     Yes          0      Graduate           Yes
# 240  LP001798   Male     Yes          2      Graduate            No
# 349  LP002138   Male     Yes          0      Graduate            No
# 369  LP002191   Male     Yes          0      Graduate            No
# 372  LP002201   Male     Yes          2      Graduate           Yes
# 444  LP002424   Male     Yes          0      Graduate            No
# 503  LP002618   Male     Yes          1  Not Graduate            No
# 523  LP002693   Male     Yes          2      Graduate           Yes
# 530  LP002717   Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 181             1916             5063.0        67.0             360.0
# 188              674             5296.0       168.0             360.0
# ...

# %%
dataframe.loc[(dataframe['CoapplicantIncome']>=5000) & (dataframe['Property_Area']=='Rural')].describe
# Out:
# <bound method NDFrame.describe of       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 181  LP001634   Male      No          0      Graduate            No
# 188  LP001644    NaN     Yes          0      Graduate           Yes
# 240  LP001798   Male     Yes          2      Graduate            No
# 349  LP002138   Male     Yes          0      Graduate            No
# 369  LP002191   Male     Yes          0      Graduate            No
# 372  LP002201   Male     Yes          2      Graduate           Yes
# 444  LP002424   Male     Yes          0      Graduate            No
# 503  LP002618   Male     Yes          1  Not Graduate            No
# 523  LP002693   Male     Yes          2      Graduate           Yes
# 530  LP002717   Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 181             1916             5063.0        67.0             360.0
# ...

# %%
#Customers having Applicant Income below 5000 and semiurban property area ... 
dataframe.loc[(dataframe['ApplicantIncome']<=5000) & (dataframe['Property_Area']=='Semiurban')]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 7    LP001014    Male     Yes         3+      Graduate            No
# 22   LP001047    Male     Yes          0  Not Graduate            No
# 24   LP001052    Male     Yes          1      Graduate           NaN
# 26   LP001068    Male     Yes          0      Graduate            No
# 29   LP001087  Female      No          2      Graduate           NaN
# ..        ...     ...     ...        ...           ...           ...
# 589  LP002926    Male     Yes          2      Graduate           Yes
# 590  LP002928    Male     Yes          0      Graduate            No
# 597  LP002943    Male      No        NaN      Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dataframe.loc[(dataframe['ApplicantIncome']<=5000) & (dataframe['Property_Area']=='Semiurban')].describe
# Out:
# <bound method NDFrame.describe of       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 7    LP001014    Male     Yes         3+      Graduate            No
# 22   LP001047    Male     Yes          0  Not Graduate            No
# 24   LP001052    Male     Yes          1      Graduate           NaN
# 26   LP001068    Male     Yes          0      Graduate            No
# 29   LP001087  Female      No          2      Graduate           NaN
# ..        ...     ...     ...        ...           ...           ...
# 589  LP002926    Male     Yes          2      Graduate           Yes
# 590  LP002928    Male     Yes          0      Graduate            No
# 597  LP002943    Male      No        NaN      Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
